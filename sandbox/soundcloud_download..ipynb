# %% [markdown]
# # Download from Soundcloud using yt-dlp

# %% [markdown]
# ## Setup the Notebook and the Dependencies

# %%
import yt_dlp
import os
from dotenv import load_dotenv
os.environ['PATH'] = r'C:\ffmpeg\bin;' + os.environ['PATH']

load_dotenv()
TOKEN = os.getenv('SC_TOKEN')
SONGLINK = "https://soundcloud.com/katyperry/last-friday-night-t-g-i-f"

# %% [markdown]
# ## Download a track as .m4a using a token to access Soundcloud Go songs

# %%
SONGLINK = "https://soundcloud.com/katyperry/last-friday-night-t-g-i-f"


ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': '%(title)s.%(ext)s',  # Output filename template
    'username': 'oauth',
    'password': TOKEN,
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([SONGLINK])

# %% [markdown]
# ## Get all the metadata to a song

# %%
with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(SONGLINK, download=False)
    
# Display all metadata
print("Available metadata:")
for key, value in info.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## Download as .mp3 with Thumbnail
#
# Download the track, convert it into mp3. Get the hightest resolution thumbnail and embed it into the mp3 file.

# %%
SONGLINK = "https://soundcloud.com/skrillex/avicii-levels-skrillex-remix"

# %%
ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': '%(artist)s - %(title)s.%(ext)s',
    'username': 'oauth',
    'password': TOKEN,
    'postprocessors': [
        {
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '320',
        },
        {
            'key': 'FFmpegMetadata',
            'add_metadata': True,
        },
        {
            'key': 'EmbedThumbnail',
            'already_have_thumbnail': False,
        },
    ],
    'writethumbnail': True,  # Download thumbnail
    'embedthumbnail': True,  # Embed it in the audio file
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    ydl.download([SONGLINK])
# Out:
# [soundcloud] Extracting URL: https://soundcloud.com/michael-big-daddy-day/captain-jack
# [soundcloud] michael-big-daddy-day/captain-jack: Downloading info JSON
# [soundcloud] 229665828: Downloading hls_aac format info JSON
# [soundcloud] 229665828: Downloading hls_aac format info JSON
# [soundcloud] 229665828: Downloading http_aac format info JSON
# [soundcloud] 229665828: Downloading hls_aac format info JSON
# [soundcloud] 229665828: Downloading hls_mp3 format info JSON
# [soundcloud] 229665828: Downloading http_mp3 format info JSON
# [info] 229665828: Downloading 1 format(s): http_aac_hq
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: NA - Captain Jack.jpg
# [download] Destination: NA - Captain Jack.m4a
# [download] 100% of    6.12MiB in 00:00:05 at 1.04MiB/s
# [FixupM4a] Correcting container of "NA - Captain Jack.m4a"
# [ExtractAudio] Destination: NA - Captain Jack.mp3
# Deleting original file NA - Captain Jack.m4a (pass -k to keep)
# [Metadata] Adding metadata to "NA - Captain Jack.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "NA - Captain Jack.mp3"

# %% [markdown]
# # Add the songlink as a comment
# When downloading a song, also embed the songlink into the mp3 as the comment tag

# %%
SONGLINK = "https://soundcloud.com/priincemuzik/moliy-silent-addy-shake-it-to-the-max-remix-feat-skillibeng-shenseea"

ydl_opts = {
    'format': 'bestaudio/best',
    'outtmpl': '%(title)s.%(ext)s',
    'username': 'oauth',
    'password': TOKEN,
    'postprocessors': [
        {
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '320',
        },
        {
            'key': 'FFmpegMetadata',
            'add_metadata': True,
        },
        {
            'key': 'EmbedThumbnail',
        },
    ],
    'writethumbnail': True,
    'embedthumbnail': True,
}

with yt_dlp.YoutubeDL(ydl_opts) as ydl:
    info = ydl.extract_info(SONGLINK, download=True)
    
    artist = info.get('artist', '').strip()
    title = info['title']
    
    # Use only title if no artist is available
    if artist and artist != '':
        mp3_file = f"{artist} - {title}.mp3"
    else:
        mp3_file = f"{title}.mp3"

# %%
from mutagen.id3 import ID3, COMM
# Add comment with the song URL to the downloaded file
audio = ID3(mp3_file)
audio.add(COMM(text=[SONGLINK]))
audio.save()

# %% [markdown]
# # Download a Playlist

# %%
from mutagen.id3 import ID3, COMM
PLAYLIST_LINK = "https://soundcloud.com/user-251038582/sets/tims-techno-remix-picks"
START_FROM_TRACK = 69  # Change to desired starting track number (1-based index)

ydl_opts_playlist = {
    'format': 'bestaudio/best',
    'outtmpl': '%(title)s.%(ext)s',
    'username': 'oauth',
    'password': TOKEN,

    'playlist_start': START_FROM_TRACK,

    'postprocessors': [
        {
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '320',
        },
        {
            'key': 'FFmpegMetadata',
            'add_metadata': True,
        },
        {
            'key': 'EmbedThumbnail',
        },
    ],
    'writethumbnail': True,
    'embedthumbnail': True,
}

with yt_dlp.YoutubeDL(ydl_opts_playlist) as ydl:
    playlist_info = ydl.extract_info(PLAYLIST_LINK, download=True)
    
    # Add song URL as comment to each downloaded track
    for entry in playlist_info['entries']:
        artist = entry.get('artist', '').strip()
        title = entry['title']
        
        # Use only title if no artist is available
        if artist and artist != '':
            mp3_file = f"{artist} - {title}.mp3"
        else:
            mp3_file = f"{title}.mp3"
        
        song_url = entry['webpage_url']
        
        audio = ID3(mp3_file)
        audio.delall('TALB')  # Remove album tag, would otherwise be set to playlist title
        audio.add(COMM(text=[song_url]))
        audio.save()
        
print(f"Downloaded {len(playlist_info['entries'])} tracks from playlist")

# %% [markdown]
# # Check for native download

# %%
SONGLINK = "https://soundcloud.com/fawafawa/liverpool-street-in-the-rain-speed-garage-edit"

ydl_opts_native = {
    'format': 'original/best',  # Prioritize original/native download over streams
    'outtmpl': '%(artist)s - %(title)s.%(ext)s',
    'username': 'oauth',
    'password': TOKEN,
}

with yt_dlp.YoutubeDL(ydl_opts_native) as ydl:
    info = ydl.extract_info(SONGLINK, download=False)
    
    # Check if original download is available
    if info.get('download_url'):
        print(f"Native download available: {info.get('ext')} format")
    else:
        print("No native download available, will use stream")
    
    ydl.download([SONGLINK])

# %% [markdown]
# # Buy / External Download available?

# %%
SONGLINK = "https://soundcloud.com/taziaus/way-2-sexy-tazi-bootleg"

# Check using yt-dlp (will fail to detect)
with yt_dlp.YoutubeDL({'username': 'oauth', 'password': TOKEN}) as ydl:
    info = ydl.extract_info(SONGLINK, download=False)
    
    # Check if external purchase/download link is available
    has_external_link_ytdlp = bool(info.get('purchase_url'))
    
    print("=== Using yt-dlp ===")
    print(f"External buy/download link available: {has_external_link_ytdlp}")
    if has_external_link_ytdlp:
        print(f"Link: {info.get('purchase_url')}")
    else:
        print("yt-dlp does NOT extract purchase_url for SoundCloud")

# %%
# Verify all available metadata fields
print("All available metadata fields:")
for key in sorted(info.keys()):
    print(f"  {key}")

# Check specifically for purchase/download related fields
purchase_fields = [k for k in info.keys() if 'purchase' in k.lower() or 'buy' in k.lower() or 'external' in k.lower()]
print(f"\nPurchase/Buy/External related fields: {purchase_fields if purchase_fields else 'None found'}")
print(f"\npurchase_url value: {info.get('purchase_url')}")

# %% [markdown]
# ## Web Scraping Solution for External Download Links
#
# **Note:** yt-dlp does NOT extract `purchase_url` for SoundCloud tracks, even when they have "Free Download" buttons. These external links (to Hypeddit, Toneden, etc.) are embedded in the webpage HTML but not exposed through SoundCloud's API.
#
# We need to scrape the SoundCloud page HTML directly to find the `purchaseLink_container` div.

# %%
import requests
from bs4 import BeautifulSoup
import re

def check_soundcloud_external_download(track_url):
    """
    Check if a SoundCloud track has an external download link (Free Download button).
    
    Args:
        track_url: SoundCloud track URL
        
    Returns:
        dict with 'has_external_link' (bool) and 'external_link' (str or None)
    """
    try:
        # Fetch the SoundCloud page HTML
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
        }
        response = requests.get(track_url, headers=headers, timeout=10)
        response.raise_for_status()
        
        # Parse HTML
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Look for the embedded JSON data in script tags
        # SoundCloud embeds track data in window.__sc_hydration
        for script in soup.find_all('script'):
            if script.string and 'window.__sc_hydration' in script.string:
                # Search for purchase_url in the JSON data
                match = re.search(r'["\']purchase_url["\']\s*:\s*["\']([^"\']+)', script.string)
                if match:
                    external_url = match.group(1)
                    # Decode unicode escapes if present
                    external_url = external_url.encode().decode('unicode_escape')
                    return {
                        'has_external_link': True,
                        'external_link': external_url
                    }
        
        return {'has_external_link': False, 'external_link': None}
        
    except Exception as e:
        print(f"Error checking external link: {e}")
        return {'has_external_link': False, 'external_link': None, 'error': str(e)}

# %%
# Test with the track that has a Free Download button
test_url = "https://soundcloud.com/taziaus/way-2-sexy-tazi-bootleg"

result = check_soundcloud_external_download(test_url)

print(f"Has external download link: {result['has_external_link']}")
if result['has_external_link']:
    print(f"External link: {result['external_link']}")
else:
    print("No external download link found")
    if 'error' in result:
        print(f"Error: {result['error']}")

# %%
# Debug: Let's examine the HTML to understand the structure
test_url = "https://soundcloud.com/taziaus/way-2-sexy-tazi-bootleg"

headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
}
response = requests.get(test_url, headers=headers, timeout=10)
soup = BeautifulSoup(response.text, 'html.parser')

# Search for any element containing "purchase" or "download"
print("=== Searching for purchase/download related elements ===\n")

# Look for any div with purchase in class name
purchase_divs = soup.find_all('div', class_=lambda x: x and 'purchase' in x.lower())
print(f"Divs with 'purchase' in class: {len(purchase_divs)}")
for div in purchase_divs[:3]:
    print(f"  Class: {div.get('class')}")
    print(f"  Content preview: {str(div)[:200]}...\n")

# Look for links with "download" text
download_links = soup.find_all('a', string=lambda x: x and 'download' in x.lower())
print(f"\nLinks with 'download' in text: {len(download_links)}")
for link in download_links[:3]:
    print(f"  Text: {link.get_text(strip=True)}")
    print(f"  Href: {link.get('href')}")
    print(f"  Classes: {link.get('class')}\n")

# %%
# Look for JSON data embedded in script tags
import json
import re

print("=== Searching for embedded JSON data ===\n")

# Find all script tags
scripts = soup.find_all('script')
print(f"Total script tags found: {len(scripts)}\n")

# Look for hydration data or initial state
for i, script in enumerate(scripts):
    script_content = script.string
    if script_content and ('purchase' in script_content.lower() or 'buy_link' in script_content.lower() or 'external_url' in script_content.lower()):
        print(f"Script {i} contains purchase/buy/external_url keywords")
        print(f"Preview: {script_content[:500]}...\n")
        
# Try to find the main data payload
for script in scripts:
    if script.string and 'window.__sc_hydration' in script.string:
        print("Found window.__sc_hydration!")
        # Try to extract and search for purchase_url
        match = re.search(r'purchase_url["\']?\s*:\s*["\']([^"\']+)', script.string)
        if match:
            print(f"Found purchase_url: {match.group(1)}")
        else:
            print("No purchase_url found in hydration data")
        break

# %%
# Test with multiple tracks to verify the function
test_tracks = [
    ("https://soundcloud.com/taziaus/way-2-sexy-tazi-bootleg", "Track with Free Download"),
    ("https://soundcloud.com/katyperry/last-friday-night-t-g-i-f", "Track without Free Download"),
]

print("=== Testing External Download Detection ===\n")
for track_url, description in test_tracks:
    print(f"{description}:")
    print(f"  URL: {track_url}")
    
    result = check_soundcloud_external_download(track_url)
    
    if result['has_external_link']:
        print(f"  ✓ External download link found: {result['external_link']}")
    else:
        print(f"  ✗ No external download link")
    print()

# %% [markdown]
# ## Summary: yt-dlp vs Web Scraping
#
# **yt-dlp limitations:**
# - `purchase_url` field is **NOT** extracted by yt-dlp's SoundCloud extractor
# - Returns `None` even when tracks have "Free Download" buttons
# - yt-dlp only uses SoundCloud's API, which doesn't expose external download links
#
# **Web scraping solution:**
# - Successfully extracts `purchase_url` from the embedded JSON in `window.__sc_hydration`
# - Works for tracks with external download links (Hypeddit, Toneden, etc.)
# - Returns `None` for tracks without external links (as expected)
#
# **Recommendation:** Use the `check_soundcloud_external_download()` function above when you need to detect external download links on SoundCloud tracks.

# %% [markdown]
# # Download a Playlist but wait in between

# %%
from mutagen.id3 import ID3, COMM
PLAYLIST_LINK = "https://soundcloud.com/user-251038582/sets/tims-minimal-house"

ydl_opts_playlist = {
    'format': 'bestaudio/best',
    'outtmpl': '%(title)s.%(ext)s',
    'username': 'oauth',
    'password': TOKEN,
    'postprocessors': [
        {
            'key': 'FFmpegExtractAudio',
            'preferredcodec': 'mp3',
            'preferredquality': '320',
        },
        {
            'key': 'FFmpegMetadata',
            'add_metadata': True,
        },
        {
            'key': 'EmbedThumbnail',
        },
    ],
    'writethumbnail': True,
    'embedthumbnail': True,
    
    # Rate limiting configuration to stay under 600 requests per 10 minutes
    # Allows ~50 tracks per 10 minutes, ~300 tracks per hour
    'sleep_requests': 1,           # 1 second between API requests during metadata extraction
    'sleep_interval': 5,             # Minimum 5 seconds between track downloads
    'max_sleep_interval': 20,         # Maximum 20 seconds between track downloads
    'extractor_retries': 10,         # Allow up to 10 retries for rate limit errors
    'retry_sleep': 'extractor:exp=1:120',  # Exponential backoff (1-120 seconds) on rate limit
    
    # Error handling - continue downloading even if individual tracks fail
    'ignoreerrors': True,            # Skip unavailable/failed tracks and continue with the rest
    'no_warnings': False,            # Still show warnings about failed tracks
}

with yt_dlp.YoutubeDL(ydl_opts_playlist) as ydl:
    playlist_info = ydl.extract_info(PLAYLIST_LINK, download=True)
    
    # Add song URL as comment to each downloaded track
    for entry in playlist_info['entries']:
        if entry is None:  # Skip entries that failed to download
            continue
            
        artist = entry.get('artist', '').strip()
        title = entry['title']
        
        mp3_file = f"{title}.mp3"
        
        song_url = entry['webpage_url']
        
        try:
            audio = ID3(mp3_file)
            audio.delall('TALB')  # Remove album tag, would otherwise be set to playlist title
            audio.add(COMM(text=[song_url]))
            audio.save()
        except Exception as e:
            print(f"Warning: Could not add metadata to {mp3_file}: {e}")
            continue
        
print(f"Downloaded {len([e for e in playlist_info['entries'] if e is not None])} tracks from playlist")

# %%
import csv
import random
import time
from pathlib import Path

def analyze_playlist_download_options(
    playlist_url: str,
    token: str,
    output_dir: str = "downloads/playlist",
    log_csv: str = "playlist_download_log.csv",
) -> None:
    """
    Analyze a SoundCloud playlist, log download options per track, and download via yt-dlp when needed.

    Rules:
    - Prefer native SoundCloud download when available (do NOT download via yt-dlp).
    - If native download is not available, download via yt-dlp (even if external link exists).
    - Always log availability and yt-dlp success/failure.
    """
    output_path = Path(output_dir)
    output_path.mkdir(parents=True, exist_ok=True)
    
    log_path = Path(log_csv)
    is_new_log = not log_path.exists()
    
    def sleep_between_tracks():
        time.sleep(random.uniform(5, 20))
    
    # Step 1: get playlist entries with minimal requests (flat extraction)
    ydl_opts_list = {
        "extract_flat": True,
        "skip_download": True,
        "username": "oauth",
        "password": token,
        "sleep_interval_requests": 5,
        "max_sleep_interval_requests": 20,
        "extractor_retries": 10,
        "retry_sleep": "extractor:exp=1:120",
        "ignoreerrors": True,
        "no_warnings": False,
    }
    
    # Step 2: per-track info (rate-limited requests)
    ydl_opts_info = {
        "format": "original/best",
        "username": "oauth",
        "password": token,
        "sleep_interval_requests": 5,
        "max_sleep_interval_requests": 20,
        "extractor_retries": 10,
        "retry_sleep": "extractor:exp=1:120",
        "ignoreerrors": True,
        "no_warnings": False,
    }
    
    # Step 3: download with SAME rate-limited options as the playlist download cell (Cell 28)
    ydl_opts_download = {
        "format": "bestaudio/best",
        "outtmpl": str(output_path / "%(title)s.%(ext)s"),
        "username": "oauth",
        "password": token,
        "postprocessors": [
            {
                "key": "FFmpegExtractAudio",
                "preferredcodec": "mp3",
                "preferredquality": "320",
            },
            {
                "key": "FFmpegMetadata",
                "add_metadata": True,
            },
            {
                "key": "EmbedThumbnail",
            },
        ],
        "writethumbnail": True,
        "embedthumbnail": True,
        "sleep_requests": 5,
        "sleep_interval": 5,
        "max_sleep_interval": 20,
        "sleep_interval_requests": 5,
        "max_sleep_interval_requests": 20,
        "extractor_retries": 10,
        "retry_sleep": "extractor:exp=1:120",
        "ignoreerrors": True,
        "no_warnings": False,
    }
    
    with open(log_path, "a", newline="", encoding="utf-8") as f:
        writer = csv.DictWriter(
            f,
            fieldnames=[
                "track_title",
                "track_url",
                "native_download_available",
                "external_link_available",
                "external_link",
                "ytdlp_downloaded",
                "ytdlp_error",
            ],
        )
        if is_new_log:
            writer.writeheader()
        
        # Get playlist entries flat to avoid bulk metadata requests
        with yt_dlp.YoutubeDL(ydl_opts_list) as ydl_list:
            playlist_info = ydl_list.extract_info(playlist_url, download=False)
            entries = playlist_info.get("entries", []) if playlist_info else []
        
        with yt_dlp.YoutubeDL(ydl_opts_info) as ydl:
            for entry in entries:
                if not entry:
                    continue
                track_url = entry.get("url") or entry.get("webpage_url")
                if not track_url:
                    continue
                
                # Fetch full track info (rate-limited per request)
                try:
                    info = ydl.extract_info(track_url, download=False)
                except Exception as e:
                    writer.writerow({
                        "track_title": entry.get("title", ""),
                        "track_url": track_url,
                        "native_download_available": False,
                        "external_link_available": False,
                        "external_link": "",
                        "ytdlp_downloaded": False,
                        "ytdlp_error": f"info_error: {e}",
                    })
                    sleep_between_tracks()
                    continue
                
                if not info:
                    writer.writerow({
                        "track_title": entry.get("title", ""),
                        "track_url": track_url,
                        "native_download_available": False,
                        "external_link_available": False,
                        "external_link": "",
                        "ytdlp_downloaded": False,
                        "ytdlp_error": "info_error: unavailable (None)",
                    })
                    sleep_between_tracks()
                    continue
                
                title = info.get("title", "")
                native_available = bool(info.get("download_url"))
                
                external_link = ""
                external_available = False
                try:
                    ext_result = check_soundcloud_external_download(track_url)
                    external_available = bool(ext_result.get("has_external_link"))
                    external_link = ext_result.get("external_link") or ""
                except Exception:
                    pass
                
                # If native download is available, prefer it (no yt-dlp download)
                if native_available:
                    writer.writerow({
                        "track_title": title,
                        "track_url": track_url,
                        "native_download_available": True,
                        "external_link_available": external_available,
                        "external_link": external_link,
                        "ytdlp_downloaded": False,
                        "ytdlp_error": "",
                    })
                    sleep_between_tracks()
                    continue
                
                # Otherwise download with yt-dlp (even if external link exists)
                ytdlp_ok = False
                ytdlp_err = ""
                try:
                    with yt_dlp.YoutubeDL(ydl_opts_download) as ydl_dl:
                        ydl_dl.download([track_url])
                    ytdlp_ok = True
                except Exception as e:
                    ytdlp_err = str(e)
                
                writer.writerow({
                    "track_title": title,
                    "track_url": track_url,
                    "native_download_available": False,
                    "external_link_available": external_available,
                    "external_link": external_link,
                    "ytdlp_downloaded": ytdlp_ok,
                    "ytdlp_error": ytdlp_err,
                })
                sleep_between_tracks()

# %%
# Example usage
PLAYLIST_LINK = "https://soundcloud.com/user-251038582/sets/10yeardancerobix"
analyze_playlist_download_options(PLAYLIST_LINK, TOKEN)
# Out:
# [soundcloud:set] Extracting URL: https://soundcloud.com/user-251038582/sets/10yeardancerobix
# [soundcloud:set] user-251038582/sets/10yeardancerobix: Downloading JSON metadata
# [download] Downloading playlist: #10YEARdancerobix
# [soundcloud:set] Playlist #10YEARdancerobix: Downloading 243 items of 243
# [download] Downloading item 1 of 243
# [download] Downloading item 2 of 243
# [download] Downloading item 3 of 243
# [download] Downloading item 4 of 243
# [download] Downloading item 5 of 243
# [download] Downloading item 6 of 243
# [download] Downloading item 7 of 243
# [download] Downloading item 8 of 243
# [download] Downloading item 9 of 243
# [download] Downloading item 10 of 243
# [download] Downloading item 11 of 243
# [download] Downloading item 12 of 243
# [download] Downloading item 13 of 243
# [download] Downloading item 14 of 243
# [download] Downloading item 15 of 243
# [download] Downloading item 16 of 243
# [download] Downloading item 17 of 243
# [download] Downloading item 18 of 243
# [download] Downloading item 19 of 243
# [download] Downloading item 20 of 243
# [download] Downloading item 21 of 243
# [download] Downloading item 22 of 243
# [download] Downloading item 23 of 243
# [download] Downloading item 24 of 243
# [download] Downloading item 25 of 243
# [download] Downloading item 26 of 243
# [download] Downloading item 27 of 243
# [download] Downloading item 28 of 243
# [download] Downloading item 29 of 243
# [download] Downloading item 30 of 243
# [download] Downloading item 31 of 243
# [download] Downloading item 32 of 243
# [download] Downloading item 33 of 243
# [download] Downloading item 34 of 243
# [download] Downloading item 35 of 243
# [download] Downloading item 36 of 243
# [download] Downloading item 37 of 243
# [download] Downloading item 38 of 243
# [download] Downloading item 39 of 243
# [download] Downloading item 40 of 243
# [download] Downloading item 41 of 243
# [download] Downloading item 42 of 243
# [download] Downloading item 43 of 243
# [download] Downloading item 44 of 243
# [download] Downloading item 45 of 243
# [download] Downloading item 46 of 243
# [download] Downloading item 47 of 243
# [download] Downloading item 48 of 243
# [download] Downloading item 49 of 243
# [download] Downloading item 50 of 243
# [download] Downloading item 51 of 243
# [download] Downloading item 52 of 243
# [download] Downloading item 53 of 243
# [download] Downloading item 54 of 243
# [download] Downloading item 55 of 243
# [download] Downloading item 56 of 243
# [download] Downloading item 57 of 243
# [download] Downloading item 58 of 243
# [download] Downloading item 59 of 243
# [download] Downloading item 60 of 243
# [download] Downloading item 61 of 243
# [download] Downloading item 62 of 243
# [download] Downloading item 63 of 243
# [download] Downloading item 64 of 243
# [download] Downloading item 65 of 243
# [download] Downloading item 66 of 243
# [download] Downloading item 67 of 243
# [download] Downloading item 68 of 243
# [download] Downloading item 69 of 243
# [download] Downloading item 70 of 243
# [download] Downloading item 71 of 243
# [download] Downloading item 72 of 243
# [download] Downloading item 73 of 243
# [download] Downloading item 74 of 243
# [download] Downloading item 75 of 243
# [download] Downloading item 76 of 243
# [download] Downloading item 77 of 243
# [download] Downloading item 78 of 243
# [download] Downloading item 79 of 243
# [download] Downloading item 80 of 243
# [download] Downloading item 81 of 243
# [download] Downloading item 82 of 243
# [download] Downloading item 83 of 243
# [download] Downloading item 84 of 243
# [download] Downloading item 85 of 243
# [download] Downloading item 86 of 243
# [download] Downloading item 87 of 243
# [download] Downloading item 88 of 243
# [download] Downloading item 89 of 243
# [download] Downloading item 90 of 243
# [download] Downloading item 91 of 243
# [download] Downloading item 92 of 243
# [download] Downloading item 93 of 243
# [download] Downloading item 94 of 243
# [download] Downloading item 95 of 243
# [download] Downloading item 96 of 243
# [download] Downloading item 97 of 243
# [download] Downloading item 98 of 243
# [download] Downloading item 99 of 243
# [download] Downloading item 100 of 243
# [download] Downloading item 101 of 243
# [download] Downloading item 102 of 243
# [download] Downloading item 103 of 243
# [download] Downloading item 104 of 243
# [download] Downloading item 105 of 243
# [download] Downloading item 106 of 243
# [download] Downloading item 107 of 243
# [download] Downloading item 108 of 243
# [download] Downloading item 109 of 243
# [download] Downloading item 110 of 243
# [download] Downloading item 111 of 243
# [download] Downloading item 112 of 243
# [download] Downloading item 113 of 243
# [download] Downloading item 114 of 243
# [download] Downloading item 115 of 243
# [download] Downloading item 116 of 243
# [download] Downloading item 117 of 243
# [download] Downloading item 118 of 243
# [download] Downloading item 119 of 243
# [download] Downloading item 120 of 243
# [download] Downloading item 121 of 243
# [download] Downloading item 122 of 243
# [download] Downloading item 123 of 243
# [download] Downloading item 124 of 243
# [download] Downloading item 125 of 243
# [download] Downloading item 126 of 243
# [download] Downloading item 127 of 243
# [download] Downloading item 128 of 243
# [download] Downloading item 129 of 243
# [download] Downloading item 130 of 243
# [download] Downloading item 131 of 243
# [download] Downloading item 132 of 243
# [download] Downloading item 133 of 243
# [download] Downloading item 134 of 243
# [download] Downloading item 135 of 243
# [download] Downloading item 136 of 243
# [download] Downloading item 137 of 243
# [download] Downloading item 138 of 243
# [download] Downloading item 139 of 243
# [download] Downloading item 140 of 243
# [download] Downloading item 141 of 243
# [download] Downloading item 142 of 243
# [download] Downloading item 143 of 243
# [download] Downloading item 144 of 243
# [download] Downloading item 145 of 243
# [download] Downloading item 146 of 243
# [download] Downloading item 147 of 243
# [download] Downloading item 148 of 243
# [download] Downloading item 149 of 243
# [download] Downloading item 150 of 243
# [download] Downloading item 151 of 243
# [download] Downloading item 152 of 243
# [download] Downloading item 153 of 243
# [download] Downloading item 154 of 243
# [download] Downloading item 155 of 243
# [download] Downloading item 156 of 243
# [download] Downloading item 157 of 243
# [download] Downloading item 158 of 243
# [download] Downloading item 159 of 243
# [download] Downloading item 160 of 243
# [download] Downloading item 161 of 243
# [download] Downloading item 162 of 243
# [download] Downloading item 163 of 243
# [download] Downloading item 164 of 243
# [download] Downloading item 165 of 243
# [download] Downloading item 166 of 243
# [download] Downloading item 167 of 243
# [download] Downloading item 168 of 243
# [download] Downloading item 169 of 243
# [download] Downloading item 170 of 243
# [download] Downloading item 171 of 243
# [download] Downloading item 172 of 243
# [download] Downloading item 173 of 243
# [download] Downloading item 174 of 243
# [download] Downloading item 175 of 243
# [download] Downloading item 176 of 243
# [download] Downloading item 177 of 243
# [download] Downloading item 178 of 243
# [download] Downloading item 179 of 243
# [download] Downloading item 180 of 243
# [download] Downloading item 181 of 243
# [download] Downloading item 182 of 243
# [download] Downloading item 183 of 243
# [download] Downloading item 184 of 243
# [download] Downloading item 185 of 243
# [download] Downloading item 186 of 243
# [download] Downloading item 187 of 243
# [download] Downloading item 188 of 243
# [download] Downloading item 189 of 243
# [download] Downloading item 190 of 243
# [download] Downloading item 191 of 243
# [download] Downloading item 192 of 243
# [download] Downloading item 193 of 243
# [download] Downloading item 194 of 243
# [download] Downloading item 195 of 243
# [download] Downloading item 196 of 243
# [download] Downloading item 197 of 243
# [download] Downloading item 198 of 243
# [download] Downloading item 199 of 243
# [download] Downloading item 200 of 243
# [download] Downloading item 201 of 243
# [download] Downloading item 202 of 243
# [download] Downloading item 203 of 243
# [download] Downloading item 204 of 243
# [download] Downloading item 205 of 243
# [download] Downloading item 206 of 243
# [download] Downloading item 207 of 243
# [download] Downloading item 208 of 243
# [download] Downloading item 209 of 243
# [download] Downloading item 210 of 243
# [download] Downloading item 211 of 243
# [download] Downloading item 212 of 243
# [download] Downloading item 213 of 243
# [download] Downloading item 214 of 243
# [download] Downloading item 215 of 243
# [download] Downloading item 216 of 243
# [download] Downloading item 217 of 243
# [download] Downloading item 218 of 243
# [download] Downloading item 219 of 243
# [download] Downloading item 220 of 243
# [download] Downloading item 221 of 243
# [download] Downloading item 222 of 243
# [download] Downloading item 223 of 243
# [download] Downloading item 224 of 243
# [download] Downloading item 225 of 243
# [download] Downloading item 226 of 243
# [download] Downloading item 227 of 243
# [download] Downloading item 228 of 243
# [download] Downloading item 229 of 243
# [download] Downloading item 230 of 243
# [download] Downloading item 231 of 243
# [download] Downloading item 232 of 243
# [download] Downloading item 233 of 243
# [download] Downloading item 234 of 243
# [download] Downloading item 235 of 243
# [download] Downloading item 236 of 243
# [download] Downloading item 237 of 243
# [download] Downloading item 238 of 243
# [download] Downloading item 239 of 243
# [download] Downloading item 240 of 243
# [download] Downloading item 241 of 243
# [download] Downloading item 242 of 243
# [download] Downloading item 243 of 243
# [download] Finished downloading playlist: #10YEARdancerobix
# [soundcloud] Extracting URL: https://soundcloud.com/kanyewest/gold-digger-album-version
# [soundcloud] kanyewest/gold-digger-album-version: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255766412: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255766412: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255766412: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://soundcloud.com/kanyewest/gold-digger-album-version
# [soundcloud] kanyewest/gold-digger-album-version: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255766412: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255766412: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255766412: Downloading hls_opus format info JSON
# [info] 255766412: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Gold Digger (feat. Jamie Foxx).jpg
# [download] Sleeping 8.93 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 23
# [download] Destination: downloads\playlist\Gold Digger (feat. Jamie Foxx).m4a
# [download] 100% of    6.45MiB in 00:00:03 at 1.75MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Gold Digger (feat. Jamie Foxx).m4a"
# [ExtractAudio] Destination: downloads\playlist\Gold Digger (feat. Jamie Foxx).mp3
# Deleting original file downloads\playlist\Gold Digger (feat. Jamie Foxx).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Gold Digger (feat. Jamie Foxx).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Gold Digger (feat. Jamie Foxx).mp3"
# [soundcloud] Extracting URL: https://soundcloud.com/madonna/4-minutes-feat-justin-1
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] madonna/4-minutes-feat-justin-1: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://soundcloud.com/madonna/4-minutes-feat-justin-1
# [soundcloud] madonna/4-minutes-feat-justin-1: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256165458: Downloading hls_opus format info JSON
# [info] 256165458: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\4 Minutes (feat. Justin Timberlake & Timbaland).jpg
# [download] Sleeping 7.55 seconds ...
# [download] Destination: downloads\playlist\4 Minutes (feat. Justin Timberlake & Timbaland).m4a
# [download] 100% of    5.89MiB in 00:00:01 at 4.13MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\4 Minutes (feat. Justin Timberlake & Timbaland).m4a"
# [ExtractAudio] Destination: downloads\playlist\4 Minutes (feat. Justin Timberlake & Timbaland).mp3
# Deleting original file downloads\playlist\4 Minutes (feat. Justin Timberlake & Timbaland).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\4 Minutes (feat. Justin Timberlake & Timbaland).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\4 Minutes (feat. Justin Timberlake & Timbaland).mp3"
# [soundcloud] Extracting URL: https://soundcloud.com/fueled_by_ramen/girls-volume-1-i-love-it-feat
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] fueled_by_ramen/girls-volume-1-i-love-it-feat: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://soundcloud.com/fueled_by_ramen/girls-volume-1-i-love-it-feat
# [soundcloud] fueled_by_ramen/girls-volume-1-i-love-it-feat: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 118311514: Downloading hls_opus format info JSON
# [info] 118311514: Downloading 1 format(s): hls_aac_256k
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Icona Pop： I Love It (feat. Charli XCX).jpg
# [download] Sleeping 17.21 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 16
# [download] Destination: downloads\playlist\Icona Pop： I Love It (feat. Charli XCX).m4a
# [download] 100% of    4.81MiB in 00:00:01 at 2.75MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Icona Pop： I Love It (feat. Charli XCX).m4a"
# [ExtractAudio] Destination: downloads\playlist\Icona Pop： I Love It (feat. Charli XCX).mp3
# Deleting original file downloads\playlist\Icona Pop： I Love It (feat. Charli XCX).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Icona Pop： I Love It (feat. Charli XCX).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Icona Pop： I Love It (feat. Charli XCX).mp3"
# ERROR: [WinError 5] Zugriff verweigert: 'downloads\\playlist\\Icona Pop： I Love It (feat. Charli XCX).temp.mp3' -> 'downloads\\playlist\\Icona Pop： I Love It (feat. Charli XCX).mp3'
# [soundcloud] Extracting URL: https://soundcloud.com/pitbull/pitbull-ne-yo-time-of-our
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] pitbull/pitbull-ne-yo-time-of-our: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://soundcloud.com/pitbull/pitbull-ne-yo-time-of-our
# [soundcloud] pitbull/pitbull-ne-yo-time-of-our: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1640518122: Downloading hls_opus format info JSON
# [info] 1640518122: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Time of Our Lives.jpg
# [download] Sleeping 19.40 seconds ...
# [download] Destination: downloads\playlist\Time of Our Lives.m4a
# [download] 100% of    7.11MiB in 00:00:01 at 6.77MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Time of Our Lives.m4a"
# [ExtractAudio] Destination: downloads\playlist\Time of Our Lives.mp3
# Deleting original file downloads\playlist\Time of Our Lives.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Time of Our Lives.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Time of Our Lives.mp3"
# [soundcloud] Extracting URL: https://soundcloud.com/black-eyed-peas-official/i-gotta-feeling-album-version
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] black-eyed-peas-official/i-gotta-feeling-album-version: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253612778: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253612778: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253612778: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://soundcloud.com/black-eyed-peas-official/i-gotta-feeling-album-version
# [soundcloud] black-eyed-peas-official/i-gotta-feeling-album-version: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253612778: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253612778: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253612778: Downloading hls_opus format info JSON
# [info] 253612778: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\I Gotta Feeling.jpg
# [download] Sleeping 19.93 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 32
# [download] Destination: downloads\playlist\I Gotta Feeling.m4a
# [download] 100% of    9.01MiB in 00:00:03 at 2.58MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\I Gotta Feeling.m4a"
# [ExtractAudio] Destination: downloads\playlist\I Gotta Feeling.mp3
# Deleting original file downloads\playlist\I Gotta Feeling.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\I Gotta Feeling.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\I Gotta Feeling.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/1772895660
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/1772895660
# [soundcloud] 1772895660: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1772895660: Downloading hls_opus format info JSON
# [info] 1772895660: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Good Feeling.jpg
# [download] Sleeping 19.06 seconds ...
# [download] Destination: downloads\playlist\Good Feeling.m4a
# [download] 100% of    7.66MiB in 00:00:02 at 3.46MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Good Feeling.m4a"
# [ExtractAudio] Destination: downloads\playlist\Good Feeling.mp3
# Deleting original file downloads\playlist\Good Feeling.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Good Feeling.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Good Feeling.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/256250242
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256250242: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256250242: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256250242: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256250242: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/256250242
# [soundcloud] 256250242: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256250242: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256250242: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256250242: Downloading hls_opus format info JSON
# [info] 256250242: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Hot N Cold.jpg
# [download] Sleeping 12.99 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 25
# [download] Destination: downloads\playlist\Hot N Cold.m4a
# [download] 100% of    6.81MiB in 00:00:02 at 2.32MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Hot N Cold.m4a"
# [ExtractAudio] Destination: downloads\playlist\Hot N Cold.mp3
# Deleting original file downloads\playlist\Hot N Cold.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Hot N Cold.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Hot N Cold.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/159966669
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/159966669
# [soundcloud] 159966669: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 159966669: Downloading hls_opus format info JSON
# [info] 159966669: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Fireball (feat. John Ryan).jpg
# [download] Sleeping 14.82 seconds ...
# [download] Destination: downloads\playlist\Fireball (feat. John Ryan).m4a
# [download] 100% of    7.29MiB in 00:00:00 at 8.79MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Fireball (feat. John Ryan).m4a"
# [ExtractAudio] Destination: downloads\playlist\Fireball (feat. John Ryan).mp3
# Deleting original file downloads\playlist\Fireball (feat. John Ryan).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Fireball (feat. John Ryan).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Fireball (feat. John Ryan).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/23907786
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 23907786: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 23907786: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 23907786: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 23907786: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/23907786
# [soundcloud] 23907786: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 23907786: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 23907786: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 23907786: Downloading hls_opus format info JSON
# [info] 23907786: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\We Found Love (Album Version).jpg
# [download] Sleeping 7.17 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 24
# [download] Destination: downloads\playlist\We Found Love (Album Version).m4a
# [download] 100% of    6.66MiB in 00:00:03 at 2.16MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\We Found Love (Album Version).m4a"
# [ExtractAudio] Destination: downloads\playlist\We Found Love (Album Version).mp3
# Deleting original file downloads\playlist\We Found Love (Album Version).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\We Found Love (Album Version).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\We Found Love (Album Version).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/255884736
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/255884736
# [soundcloud] 255884736: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255884736: Downloading hls_opus format info JSON
# [info] 255884736: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Feel So Close (Radio Edit).jpg
# [download] Sleeping 11.92 seconds ...
# [download] Destination: downloads\playlist\Feel So Close (Radio Edit).m4a
# [download] 100% of    6.39MiB in 00:00:01 at 3.21MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Feel So Close (Radio Edit).m4a"
# [ExtractAudio] Destination: downloads\playlist\Feel So Close (Radio Edit).mp3
# Deleting original file downloads\playlist\Feel So Close (Radio Edit).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Feel So Close (Radio Edit).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Feel So Close (Radio Edit).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/1611037203
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/1611037203
# [soundcloud] 1611037203: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1611037203: Downloading hls_opus format info JSON
# [info] 1611037203: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\greedy.jpg
# [download] Sleeping 10.02 seconds ...
# [download] Destination: downloads\playlist\greedy.m4a
# [download] 100% of    4.05MiB in 00:00:00 at 4.25MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\greedy.m4a"
# [ExtractAudio] Destination: downloads\playlist\greedy.mp3
# Deleting original file downloads\playlist\greedy.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\greedy.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\greedy.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/1944875567
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/1944875567
# [soundcloud] 1944875567: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1944875567: Downloading hls_opus format info JSON
# [info] 1944875567: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\CHRYSTAL - THE DAYS [NOTION REMIX].png
# [download] Sleeping 19.51 seconds ...
# [download] Destination: downloads\playlist\CHRYSTAL - THE DAYS [NOTION REMIX].m4a
# [download] 100% of    7.18MiB in 00:00:01 at 4.18MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\CHRYSTAL - THE DAYS [NOTION REMIX].m4a"
# [ExtractAudio] Destination: downloads\playlist\CHRYSTAL - THE DAYS [NOTION REMIX].mp3
# Deleting original file downloads\playlist\CHRYSTAL - THE DAYS [NOTION REMIX].m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\CHRYSTAL - THE DAYS [NOTION REMIX].mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\CHRYSTAL - THE DAYS [NOTION REMIX].mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/163279606
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/163279606
# [soundcloud] 163279606: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 163279606: Downloading hls_opus format info JSON
# [info] 163279606: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Break the Rules.jpg
# [download] Sleeping 18.43 seconds ...
# [download] Destination: downloads\playlist\Break the Rules.m4a
# [download] 100% of    6.31MiB in 00:00:00 at 7.64MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Break the Rules.m4a"
# [ExtractAudio] Destination: downloads\playlist\Break the Rules.mp3
# Deleting original file downloads\playlist\Break the Rules.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Break the Rules.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Break the Rules.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/255992805
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/255992805
# [soundcloud] 255992805: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255992805: Downloading hls_opus format info JSON
# [info] 255992805: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Hotel Room Service.jpg
# [download] Sleeping 7.95 seconds ...
# [download] Destination: downloads\playlist\Hotel Room Service.m4a
# [download] 100% of    7.38MiB in 00:00:01 at 4.22MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Hotel Room Service.m4a"
# [ExtractAudio] Destination: downloads\playlist\Hotel Room Service.mp3
# Deleting original file downloads\playlist\Hotel Room Service.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Hotel Room Service.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Hotel Room Service.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/252971475
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252971475: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252971475: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252971475: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252971475: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/252971475
# [soundcloud] 252971475: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252971475: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252971475: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252971475: Downloading hls_opus format info JSON
# [info] 252971475: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Party Rock Anthem (feat. Lauren Bennett & GoonRock).jpg
# [download] Sleeping 14.56 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 29
# [download] Destination: downloads\playlist\Party Rock Anthem (feat. Lauren Bennett & GoonRock).m4a
# [download] 100% of    8.12MiB in 00:00:03 at 2.50MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Party Rock Anthem (feat. Lauren Bennett & GoonRock).m4a"
# [ExtractAudio] Destination: downloads\playlist\Party Rock Anthem (feat. Lauren Bennett & GoonRock).mp3
# Deleting original file downloads\playlist\Party Rock Anthem (feat. Lauren Bennett & GoonRock).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Party Rock Anthem (feat. Lauren Bennett & GoonRock).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Party Rock Anthem (feat. Lauren Bennett & GoonRock).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/255769996
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255769996: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255769996: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255769996: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255769996: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/255769996
# [soundcloud] 255769996: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255769996: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255769996: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255769996: Downloading hls_opus format info JSON
# [info] 255769996: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\SOS (Album Version).jpg
# [download] Sleeping 19.90 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 26
# [download] Destination: downloads\playlist\SOS (Album Version).m4a
# [download] 100% of    7.40MiB in 00:00:03 at 2.09MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\SOS (Album Version).m4a"
# [ExtractAudio] Destination: downloads\playlist\SOS (Album Version).mp3
# Deleting original file downloads\playlist\SOS (Album Version).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\SOS (Album Version).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\SOS (Album Version).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/275580580
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 275580580: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 275580580: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 275580580: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 275580580: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/275580580
# [soundcloud] 275580580: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 275580580: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 275580580: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 275580580: Downloading hls_opus format info JSON
# [info] 275580580: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\The Way I Are (feat. Keri Hilson & D.O.E.).jpg
# [download] Sleeping 19.28 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 20
# [download] Destination: downloads\playlist\The Way I Are (feat. Keri Hilson & D.O.E.).m4a
# [download] 100% of    5.57MiB in 00:00:02 at 2.00MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\The Way I Are (feat. Keri Hilson & D.O.E.).m4a"
# [ExtractAudio] Destination: downloads\playlist\The Way I Are (feat. Keri Hilson & D.O.E.).mp3
# Deleting original file downloads\playlist\The Way I Are (feat. Keri Hilson & D.O.E.).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\The Way I Are (feat. Keri Hilson & D.O.E.).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\The Way I Are (feat. Keri Hilson & D.O.E.).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/256110526
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/256110526
# [soundcloud] 256110526: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256110526: Downloading hls_opus format info JSON
# [info] 256110526: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Die Young.jpg
# [download] Sleeping 17.59 seconds ...
# [download] Destination: downloads\playlist\Die Young.m4a
# [download] 100% of    6.56MiB in 00:00:01 at 3.81MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Die Young.m4a"
# [ExtractAudio] Destination: downloads\playlist\Die Young.mp3
# Deleting original file downloads\playlist\Die Young.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Die Young.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Die Young.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/253184404
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253184404: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253184404: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253184404: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253184404: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/253184404
# [soundcloud] 253184404: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253184404: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253184404: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253184404: Downloading hls_opus format info JSON
# [info] 253184404: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Promiscuous (feat. Timbaland).jpg
# [download] Sleeping 10.84 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 27
# [download] Destination: downloads\playlist\Promiscuous (feat. Timbaland).m4a
# [download] 100% of    7.54MiB in 00:00:03 at 2.33MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Promiscuous (feat. Timbaland).m4a"
# [ExtractAudio] Destination: downloads\playlist\Promiscuous (feat. Timbaland).mp3
# Deleting original file downloads\playlist\Promiscuous (feat. Timbaland).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Promiscuous (feat. Timbaland).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Promiscuous (feat. Timbaland).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/185688571
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 185688571: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 185688571: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 185688571: Downloading hls_mp3 format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/185688571
# [soundcloud] 185688571: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 185688571: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 185688571: Downloading hls_mp3 format info JSON
# [info] 185688571: Downloading 1 format(s): hls_aac_hq
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Talking Body.jpg
# [download] Sleeping 17.59 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 26
# [download] Destination: downloads\playlist\Talking Body.m4a
# [download] 100% of    7.35MiB in 00:00:05 at 1.38MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Talking Body.m4a"
# [ExtractAudio] Destination: downloads\playlist\Talking Body.mp3
# Deleting original file downloads\playlist\Talking Body.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Talking Body.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Talking Body.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/1634470338
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/1634470338
# [soundcloud] 1634470338: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 1634470338: Downloading hls_opus format info JSON
# [info] 1634470338: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Since U Been Gone.jpg
# [download] Sleeping 15.60 seconds ...
# [download] Destination: downloads\playlist\Since U Been Gone.m4a
# [download] 100% of    5.84MiB in 00:00:01 at 2.97MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Since U Been Gone.m4a"
# [ExtractAudio] Destination: downloads\playlist\Since U Been Gone.mp3
# Deleting original file downloads\playlist\Since U Been Gone.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Since U Been Gone.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Since U Been Gone.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/253579436
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253579436: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253579436: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253579436: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253579436: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/253579436
# [soundcloud] 253579436: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253579436: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253579436: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253579436: Downloading hls_opus format info JSON
# [info] 253579436: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Meet Me Halfway.jpg
# [download] Sleeping 14.00 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 31
# [download] Destination: downloads\playlist\Meet Me Halfway.m4a
# [download] 100% of    8.82MiB in 00:00:09 at 905.25KiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Meet Me Halfway.m4a"
# [ExtractAudio] Destination: downloads\playlist\Meet Me Halfway.mp3
# Deleting original file downloads\playlist\Meet Me Halfway.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Meet Me Halfway.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Meet Me Halfway.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/255793175
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255793175: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255793175: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255793175: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255793175: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/255793175
# [soundcloud] 255793175: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255793175: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255793175: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 255793175: Downloading hls_opus format info JSON
# [info] 255793175: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Fancy (feat. Charli XCX).jpg
# [download] Sleeping 10.01 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 22
# [download] Destination: downloads\playlist\Fancy (feat. Charli XCX).m4a
# [download] 100% of    6.20MiB in 00:00:03 at 1.95MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Fancy (feat. Charli XCX).m4a"
# [ExtractAudio] Destination: downloads\playlist\Fancy (feat. Charli XCX).mp3
# Deleting original file downloads\playlist\Fancy (feat. Charli XCX).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Fancy (feat. Charli XCX).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Fancy (feat. Charli XCX).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/252797301
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252797301: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252797301: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252797301: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252797301: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/252797301
# [soundcloud] 252797301: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252797301: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252797301: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 252797301: Downloading hls_opus format info JSON
# [info] 252797301: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Maneater.jpg
# [download] Sleeping 15.98 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 20
# [download] Destination: downloads\playlist\Maneater.m4a
# [download] 100% of    5.49MiB in 00:00:02 at 2.02MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Maneater.m4a"
# [ExtractAudio] Destination: downloads\playlist\Maneater.mp3
# Deleting original file downloads\playlist\Maneater.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Maneater.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Maneater.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/256271854
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/256271854
# [soundcloud] 256271854: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256271854: Downloading hls_opus format info JSON
# [info] 256271854: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Gimme More.jpg
# [download] Sleeping 6.96 seconds ...
# [download] Destination: downloads\playlist\Gimme More.m4a
# [download] 100% of    7.79MiB in 00:00:01 at 4.90MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Gimme More.m4a"
# [ExtractAudio] Destination: downloads\playlist\Gimme More.mp3
# Deleting original file downloads\playlist\Gimme More.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Gimme More.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Gimme More.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/256285764
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/256285764
# [soundcloud] 256285764: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 256285764: Downloading hls_opus format info JSON
# [info] 256285764: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Everybody (Backstreet's Back) (Radio Edit).jpg
# [download] Sleeping 5.43 seconds ...
# [download] Destination: downloads\playlist\Everybody (Backstreet's Back) (Radio Edit).m4a
# [download] 100% of    6.97MiB in 00:00:00 at 7.44MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Everybody (Backstreet's Back) (Radio Edit).m4a"
# [ExtractAudio] Destination: downloads\playlist\Everybody (Backstreet's Back) (Radio Edit).mp3
# Deleting original file downloads\playlist\Everybody (Backstreet's Back) (Radio Edit).m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Everybody (Backstreet's Back) (Radio Edit).mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Everybody (Backstreet's Back) (Radio Edit).mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/253514798
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253514798: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253514798: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253514798: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253514798: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/253514798
# [soundcloud] 253514798: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253514798: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253514798: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 253514798: Downloading hls_opus format info JSON
# [info] 253514798: Downloading 1 format(s): hls_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Be My Lover.jpg
# [download] Sleeping 15.03 seconds ...
# [hlsnative] Downloading m3u8 manifest
# [hlsnative] Total fragments: 27
# [download] Destination: downloads\playlist\Be My Lover.m4a
# [download] 100% of    7.45MiB in 00:00:03 at 2.44MiB/s
# [FixupM4a] Correcting container of "downloads\playlist\Be My Lover.m4a"
# [ExtractAudio] Destination: downloads\playlist\Be My Lover.mp3
# Deleting original file downloads\playlist\Be My Lover.m4a (pass -k to keep)
# [Metadata] Adding metadata to "downloads\playlist\Be My Lover.mp3"
# [EmbedThumbnail] ffmpeg: Adding thumbnail to "downloads\playlist\Be My Lover.mp3"
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/759267862
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_opus format info JSON
# [soundcloud] Extracting URL: https://api-v2.soundcloud.com/tracks/759267862
# [soundcloud] 759267862: Downloading info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading http_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_aac format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading http_mp3 format info JSON
# [soundcloud] Sleeping 5 seconds ...
# [soundcloud] 759267862: Downloading hls_opus format info JSON
# [info] 759267862: Downloading 1 format(s): http_aac_1_0
# [info] Downloading video thumbnail original ...
# [info] Writing video thumbnail original to: downloads\playlist\Alex Gaudino Feat. Crystal Waters - Destination Calabria (Original Extended Mix).jpg
# [download] Sleeping 12.33 seconds ...
